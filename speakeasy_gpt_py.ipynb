# %% [markdown]
# # Speakeasy GPT
# Speakeasy GPT is a Jupyter notebook that utilizes several natural language processing utilities to provide a seamless and low-latency speech interface to ChatGPT and other large language models.
#
# Voice prompts are transcribed using OpenAI's whisper model, run locally on CPU or GPU.  The transcription is sent as a prompt to the OpenAI gpt-3.5.turbo API.  The response is synthesized into speech by several text to speech engines, including ElevenLabs' API, Mimic 3, and Coqui TTS.

# %% [markdown]
# ## Mount Drive

# %%
import os
from google.colab import drive
nb_dir = '/content/drive/MyDrive/COLAB/speakeasy-gpt'
drive.mount('/content/drive/',force_remount=True)
if not os.path.exists(nb_dir):
    os.makedirs(nb_dir)
os.chdir(nb_dir)
print('Current path: ' + os.getcwd())
# Out:
# Mounted at /content/drive/
# Current path: /content/drive/MyDrive/COLAB/speakeasy-gpt

# %% [markdown]
# ## Installs

# %%
# !sudo apt-get install espeak
# !pip install -q elevenlabs git+https://github.com/openai/whisper.git openai ffmpeg-python pydub TTS pytictoc
# !pip install -q mycroft-mimic3-tts
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# espeak is already the newest version (1.48.04+dfsg-8build1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.4/653.4 kB 61.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 26.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.8 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for unidic-lite (setup.py) ... done
#   Building wheel for bnnumerizer (setup.py) ... done
#   Building wheel for gruut-ipa (setup.py) ... done
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done
#   Building wheel for gruut (setup.py) ... done
#   Building wheel for jsonmerge (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mycroft-mimic3-tts
#   Using cached mycroft_mimic3_tts-0.2.4.tar.gz (131 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dataclasses-json<1.0 (from mycroft-mimic3-tts)
#   Using cached dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting epitran==1.17 (from mycroft-mimic3-tts)
#   Using cached epitran-1.17-py2.py3-none-any.whl (153 kB)
# Collecting espeak-phonemizer<2.0,>=1.0 (from mycroft-mimic3-tts)
#   Using cached espeak_phonemizer-1.3.0.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gruut<3.0,>=2.3.0 (from mycroft-mimic3-tts)
#   Using cached gruut-2.3.4.tar.gz (74 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from mycroft-mimic3-tts) (1.22.4)
# Collecting onnxruntime<2.0,>=1.6 (from mycroft-mimic3-tts)
#   Using cached onnxruntime-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Collecting phonemes2ids<2.0 (from mycroft-mimic3-tts)
#   Using cached phonemes2ids-1.2.2.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting quart<1.0,>=0.16 (from mycroft-mimic3-tts)
#   Using cached quart-0.18.4-py3-none-any.whl (100 kB)
# Collecting quart-cors (from mycroft-mimic3-tts)
#   Using cached quart_cors-0.6.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from mycroft-mimic3-tts) (2.27.1)
# Collecting swagger-ui-py<22,>=21 (from mycroft-mimic3-tts)
#   Using cached swagger_ui_py-21.12.8-py3-none-any.whl (13.3 MB)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/lib/python3.10/dist-packages (from mycroft-mimic3-tts) (4.65.0)
# Collecting xdgenvpy<3,>2.0 (from mycroft-mimic3-tts)
#   Using cached xdgenvpy-2.3.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from epitran==1.17->mycroft-mimic3-tts) (67.7.2)
# Collecting unicodecsv (from epitran==1.17->mycroft-mimic3-tts)
#   Using cached unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from epitran==1.17->mycroft-mimic3-tts) (2022.10.31)
# Collecting panphon>=0.19 (from epitran==1.17->mycroft-mimic3-tts)
#   Using cached panphon-0.20.0-py2.py3-none-any.whl (73 kB)
# Collecting marisa-trie (from epitran==1.17->mycroft-mimic3-tts)
#   Using cached marisa_trie-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json<1.0->mycroft-mimic3-tts)
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.0 MB/s eta 0:00:00
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json<1.0->mycroft-mimic3-tts)
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0 (from dataclasses-json<1.0->mycroft-mimic3-tts)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2.12.1)
# Requirement already satisfied: dateparser~=1.1.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (0.13.0)
# Requirement already satisfied: gruut_lang_en~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2.0.0)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2.8.8)
# Requirement already satisfied: num2words<1.0.0,>=0.5.10 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (0.5.12)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.10/dist-packages (from gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (0.9.9)
# Collecting coloredlogs (from onnxruntime<2.0,>=1.6->mycroft-mimic3-tts)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.6->mycroft-mimic3-tts) (23.3.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.6->mycroft-mimic3-tts) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.6->mycroft-mimic3-tts) (3.19.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.6->mycroft-mimic3-tts) (1.11.1)
# Collecting aiofiles (from quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting blinker<1.6 (from quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from quart<1.0,>=0.16->mycroft-mimic3-tts) (8.1.3)
# Collecting hypercorn>=0.11.2 (from quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading Hypercorn-0.14.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.10/dist-packages (from quart<1.0,>=0.16->mycroft-mimic3-tts) (2.1.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from quart<1.0,>=0.16->mycroft-mimic3-tts) (3.1.2)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from quart<1.0,>=0.16->mycroft-mimic3-tts) (2.1.2)
# Requirement already satisfied: werkzeug>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from quart<1.0,>=0.16->mycroft-mimic3-tts) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->mycroft-mimic3-tts) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->mycroft-mimic3-tts) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->mycroft-mimic3-tts) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->mycroft-mimic3-tts) (3.4)
# Requirement already satisfied: PyYaml>=5.0 in /usr/local/lib/python3.10/dist-packages (from swagger-ui-py<22,>=21->mycroft-mimic3-tts) (6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2022.7.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (4.3)
# Collecting h11 (from hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# Collecting h2>=3.1.0 (from hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.6 MB/s eta 0:00:00
# Collecting priority (from hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts) (0.10.2)
# Collecting wsproto>=0.14.0 (from hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonlines~=1.2.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (1.16.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words<1.0.0,>=0.5.10->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (0.6.2)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from panphon>=0.19->epitran==1.17->mycroft-mimic3-tts) (0.6.2)
# Collecting munkres (from panphon>=0.19->epitran==1.17->mycroft-mimic3-tts)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.4.0->dataclasses-json<1.0->mycroft-mimic3-tts)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.4.0->dataclasses-json<1.0->mycroft-mimic3-tts) (4.5.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2.0,>=1.6->mycroft-mimic3-tts)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2.0,>=1.6->mycroft-mimic3-tts) (1.3.0)
# Collecting hyperframe<7,>=6.0 (from h2>=3.1.0->hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2>=3.1.0->hypercorn>=0.11.2->quart<1.0,>=0.16->mycroft-mimic3-tts)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->dateparser~=1.1.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->dateparser~=1.1.0->gruut<3.0,>=2.3.0->mycroft-mimic3-tts) (2023.3)
# Building wheels for collected packages: mycroft-mimic3-tts, espeak-phonemizer, gruut, phonemes2ids, unicodecsv
#   Building wheel for mycroft-mimic3-tts (setup.py) ... done
#   Created wheel for mycroft-mimic3-tts: filename=mycroft_mimic3_tts-0.2.4-py3-none-any.whl size=137751 sha256=de3259ba1570f44d8c719e29bd5093e3597ae64645fc4c54b2381c3b34d0f9a4
#   Stored in directory: /root/.cache/pip/wheels/6e/3d/29/de5c8c5b76c876501c10640e5be9e826bccd2c8fadcb67418e
#   Building wheel for espeak-phonemizer (setup.py) ... done
#   Created wheel for espeak-phonemizer: filename=espeak_phonemizer-1.3.0-py3-none-any.whl size=19772 sha256=de18f0b9b15d5ee19bd616fd5bfa5518d5ee8ac4aa26a40c52e058cdfc498644
#   Stored in directory: /root/.cache/pip/wheels/00/ef/fc/3f42969b1672300e2d0a329e464689a92d0c5a49b3aa3251b5
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-2.3.4-py3-none-any.whl size=76406 sha256=0160b8918fc8136db58f46fdda79015b25fe767ce9d8c5740930396651a034d1
#   Stored in directory: /root/.cache/pip/wheels/05/72/07/84c4d0209dc3d4b7ce8dcfe1ebe4cf967403f3b4b9f9ba981c
#   Building wheel for phonemes2ids (setup.py) ... done
#   Created wheel for phonemes2ids: filename=phonemes2ids-1.2.2-py3-none-any.whl size=14473 sha256=1788664eefb9c3e688c3b68c5cfd9a8aac79474e503c086136305ab09a81dd51
#   Stored in directory: /root/.cache/pip/wheels/03/14/94/89c3f577c522d1a7da862208ce1fcf12c186fa82fcae5d0439
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10745 sha256=e0a19a1e88d64a982c96ca68113ab1ade07bf60ff9c5d5bade4ff0012de2600c
#   Stored in directory: /root/.cache/pip/wheels/9c/ea/66/8e45247b09052a933eb1a680b7c64802298faba58aac9b346b
# Successfully built mycroft-mimic3-tts espeak-phonemizer gruut phonemes2ids unicodecsv
# Installing collected packages: xdgenvpy, unicodecsv, phonemes2ids, munkres, espeak-phonemizer, priority, panphon, mypy-extensions, marshmallow, marisa-trie, hyperframe, humanfriendly, hpack, h11, blinker, aiofiles, wsproto, typing-inspect, swagger-ui-py, marshmallow-enum, h2, epitran, coloredlogs, onnxruntime, hypercorn, dataclasses-json, quart, gruut, quart-cors, mycroft-mimic3-tts
#   Attempting uninstall: gruut
#     Found existing installation: gruut 2.2.3
#     Uninstalling gruut-2.2.3:
#       Successfully uninstalled gruut-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.14.0 requires gruut[de,es,fr]==2.2.3, but you have gruut 2.3.4 which is incompatible.
# Successfully installed aiofiles-23.1.0 blinker-1.5 coloredlogs-15.0.1 dataclasses-json-0.5.7 epitran-1.17 espeak-phonemizer-1.3.0 gruut-2.3.4 h11-0.14.0 h2-4.1.0 hpack-4.0.0 humanfriendly-10.0 hypercorn-0.14.3 hyperframe-6.0.1 marisa-trie-0.8.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 munkres-1.1.4 mycroft-mimic3-tts-0.2.4 mypy-extensions-1.0.0 onnxruntime-1.15.0 panphon-0.20.0 phonemes2ids-1.2.2 priority-2.0.0 quart-0.18.4 quart-cors-0.6.0 swagger-ui-py-21.12.8 typing-inspect-0.9.0 unicodecsv-0.14.1 wsproto-1.2.0 xdgenvpy-2.3.5

# %% [markdown]
# ## Imports

# %%
# Imports
# System
import sys
import ipywidgets as widgets
import warnings
from pytictoc import TicToc
import time

# Audio
from IPython.display import display
import scipy.io.wavfile as wav
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
from scipy.io.wavfile import write as wav_write
import io
import ffmpeg
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode
from io import BytesIO

# LLM
import openai

# STT
import whisper

# TTS
from elevenlabs import generate, play
from mimic3_tts import (
    AudioResult,
    Mimic3Settings,
    Mimic3TextToSpeechSystem,
    SSMLSpeaker,
)
from TTS.api import TTS

# Notebook settings
warnings.filterwarnings("ignore", category=UserWarning)
t = TicToc()

# %% [markdown]
# ## Check CUDA

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Load Whisper

# %%
# !wget -O test.wav http://www.voiptroubleshooter.com/open_speech/american/OSR_us_000_0061_8k.wav 

whisper_model = whisper.load_model('base.en')
t.tic()
transcription = whisper_model.transcribe("test.wav")['text']
t.toc()
sentences = [sentence + '.' for sentence in transcription.split('.')[:-1]]
for sentence in sentences: print(sentence)
# Out:
# --2023-06-01 04:38:04--  http://www.voiptroubleshooter.com/open_speech/american/OSR_us_000_0061_8k.wav
# Resolving www.voiptroubleshooter.com (www.voiptroubleshooter.com)... 162.241.218.124
# Connecting to www.voiptroubleshooter.com (www.voiptroubleshooter.com)|162.241.218.124|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 857512 (837K) [audio/x-wav]
# Saving to: ‘test.wav’
#
# test.wav            100%[===================>] 837.41K  --.-KB/s    in 0.1s
#
# 2023-06-01 04:38:05 (6.13 MB/s) - ‘test.wav’ saved [857512/857512]
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 63.6MiB/s]
# Elapsed time is 8.288790 seconds.
#  The mute muffled the high tones of the horn.
#  The gold ring fits only a pierced ear.
#  The old pan was covered with hard fudge.
#  Watch the log float in the wide river.
#  The node on the stock of wheat grew daily.
#  The heap of fallen leaves was set on fire.
#  Right fast if you want to finish early.
#  His shirt was clean, but one button was gone.
#  The barrel of beer was a brew of malt and hops.
#  Tin cans are absent from store shelves.

# %% [markdown]
# ## Load Mimic TTS

# %%
mimic = Mimic3TextToSpeechSystem(settings=Mimic3Settings(
    voice='en_US/hifi-tts_low',
    speaker='92',
    noise_w=0.2,
    rate=0.7,
    length_scale=1,
    use_deterministic_compute=True
))
_ = mimic.text_to_wav('Initializing...');

t.tic()
result = mimic.text_to_wav("I'm sorry Dave. I'm afraid I can't do that.")
t.toc()
play(result,notebook=True)
# Out:
# Elapsed time is 0.476969 seconds.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Load Coqui TTS

# %%
tts = TTS(model_name="tts_models/en/vctk/vits", progress_bar=False, gpu=False)
print('CPU Performance:')
tts.tts_to_file(text="I'm sorry Dave. I'm afraid I can't do that.", speaker='p227', file_path='test.mp3', speed=1)
# Out:
#  > Downloading model to /root/.local/share/tts/tts_models--en--vctk--vits
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.
# CPU Performance:
#  > Text splitted to sentences.
# ["I'm sorry Dave.", "I'm afraid I can't do that."]
#  > Processing time: 3.392888307571411
#  > Real-time factor: 0.9802566454657968
# 'test.mp3'

# %%
tts = TTS(model_name="tts_models/en/vctk/vits", progress_bar=False, gpu=True)
print('GPU Performance:')
tts.tts_to_file(text="I'm sorry Dave. I'm afraid I can't do that.", speaker='p227', file_path='test.mp3', speed=1)
# Out:
#  > tts_models/en/vctk/vits is already downloaded.
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.
# GPU Performance:
#  > Text splitted to sentences.
# ["I'm sorry Dave.", "I'm afraid I can't do that."]
#  > Processing time: 0.9791631698608398
#  > Real-time factor: 0.2848056655686935
# 'test.mp3'

# %% [markdown]
# ## Load ElevenLabs

# %%
t.tic()
audio = generate(
  text="This is a test.  One two three. Souncheck check check.",
  voice="Bella",
  model="eleven_monolingual_v1"
)
t.toc()

play(audio,notebook=True)
# Out:
# Elapsed time is 1.331317 seconds.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Load ChatGPT

# %%
API_KEY = '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'
openai.my_api_key = API_KEY

# %%
messages = [ {"role": "system", "content": "You are a intelligent assistant.  Answer my questions in less than 20 words.  Keep your responses simple and as short as possible.  Optimize your outputs for speech synthesis.  Instead of using parentheses, use a comma and the appropriate conjunction."} ]

# %% [markdown]
# ## Record prompt from microphone

# %%
#@title
RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=5, save_file='output.wav'):
    print('Recording...')
    sys.stdout.flush()
    display(Javascript(RECORD))
    s = output.eval_js('record(%d)' % (sec*1000))
    print('Recording ended!')
    sys.stdout.flush()
    b = b64decode(s.split(',')[1])
    with open(save_file,'wb') as f:
        f.write(b)

# %%
record(5, save_file = 'prompt_audio.wav')
# Out:
# Recording...
# Recording ended!

# %% [markdown]
# ## Transcribe prompt audio to text prompt

# %%
t.tic()
whisper_prompt = whisper_model.transcribe("prompt_audio.wav")['text'][1:]
t.toc()
print(whisper_prompt)
# Out:
# Elapsed time is 0.531142 seconds.
# Repeat after me. I'm sorry Dave. I'm afraid I can't do that.

# %% [markdown]
# ## Prompt ChatGPT

# %%
messages.append(
    {"role": "user", "content": whisper_prompt},
)
t.tic()
chat = openai.ChatCompletion.create(
    openai.my_api_key, model="gpt-3.5-turbo", messages=messages,
)
t.toc()
    
reply = chat.choices[0].message.content
print(f"ChatGPT: {reply}")
messages.append({"role": "assistant", "content": reply})
# Out:
# Elapsed time is 1.510004 seconds.
# ChatGPT: I'm sorry Dave. I'm afraid I can't do that.

# %% [markdown]
# ## Generate response audio

# %%
audio = generate(
  text=reply,
  voice="Bella",
  model="eleven_monolingual_v1"
)

play(audio,notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Record prompt audio (testing purposes)

# %%
record(7, save_file = 'prompt_audio.wav')
# Out:
# Recording...
# Recording ended!

# %% [markdown]
# ## Full loop -- ElevenLabs TTS

# %%
t.tic();

# Transcribe audio
whisper_prompt = whisper_model.transcribe("prompt_audio.wav")['text'][1:]
print(whisper_prompt)

# Append transcription to chatGPT history
messages.append(
    {"role": "user", "content": whisper_prompt},
)

# Prompt chatGPT
chat = openai.ChatCompletion.create(
    openai.my_api_key, model="gpt-3.5-turbo", messages=messages,
)
    
# Receive reply and append to chatGPT history
reply = chat.choices[0].message.content
print(f"ChatGPT: {reply}")
messages.append({"role": "assistant", "content": reply})

# Generate audio for reply
audio = generate(
  text=reply,
  voice="Bella",
  model="eleven_monolingual_v1"
)

t.toc()

# Play reply audio
play(audio,notebook=True)
# Out:
# Why did vans make a Peanuts themed shoe?
# ChatGPT: Vans created a Peanuts themed shoe to showcase their creativity and artisanship while paying tribute to the beloved characters of the Peanuts comic strip and offering fans a new way to engage with the brand.
# Elapsed time is 7.809531 seconds.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Full loop -- Coqui TTS

# %%
t.tic()

# Transcribe audio
whisper_prompt = whisper_model.transcribe("prompt_audio.wav")['text'][1:]
print(whisper_prompt)

# Append transcription to chatGPT history
messages.append(
    {"role": "user", "content": whisper_prompt},
)

# Prompt chatGPT
chat = openai.ChatCompletion.create(
    openai.my_api_key, model="gpt-3.5-turbo", messages=messages,
)
    
# Receive reply and append to chatGPT history
reply = chat.choices[0].message.content
print(f"ChatGPT: {reply}")
messages.append({"role": "assistant", "content": reply})

# Generate audio for reply
tts.tts_to_file(text=reply, speaker='p227', file_path='test.wav', speed=1)

t.toc()
Audio("test.wav",autoplay=True)
# Out:
# Why did vans make a Peanuts themed shoe?
# ChatGPT: Vans created a Peanuts themed shoe to tap into the nostalgia and cultural significance of the Peanuts comic strip, while also providing fans with a fresh and unique style option.
#  > Text splitted to sentences.
# ['Vans created a Peanuts themed shoe to tap into the nostalgia and cultural significance of the Peanuts comic strip, while also providing fans with a fresh and unique style option.']
#  > Processing time: 0.34844374656677246
#  > Real-time factor: 0.04022778237725838
# Elapsed time is 3.925959 seconds.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Full loop -- Mimic TTS

# %%
t.tic()

# Transcribe audio
whisper_prompt = whisper_model.transcribe("prompt_audio.wav")['text'][1:]
print(whisper_prompt)

# Append transcription to chatGPT history
messages.append(
    {"role": "user", "content": whisper_prompt},
)

# Prompt chatGPT
chat = openai.ChatCompletion.create(
    openai.my_api_key, model="gpt-3.5-turbo", messages=messages,
)
    
# Receive reply and append to chatGPT history
reply = chat.choices[0].message.content
print(f"ChatGPT: {reply}")
messages.append({"role": "assistant", "content": reply})

# Generate audio for reply
result = mimic.text_to_wav(reply)

t.toc()
Audio(result,autoplay=True)
# Out:
# Why did vans make a Peanuts themed shoe?
# ChatGPT: Vans made a Peanuts themed shoe as a collaboration with Peanuts Worldwide LLC to create a new and unique product line that would appeal to fans of both brands and offer a fresh and playful addition to the footwear market.
# Elapsed time is 7.352780 seconds.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Print prompt file size
print('Prompt file size:  ' + format((1/1024)*(os.path.getsize('prompt_audio.wav')),'.2f') + ' kb')

# Print response file size
print('Response file size:  ' + format((1/1024)*(os.path.getsize('test.wav')),'.2f') + ' kb')
# Out:
# Prompt file size:  42.13 kb
# Response file size:  108.57 kb
